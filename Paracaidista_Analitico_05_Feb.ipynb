# %%
import math
g = 9.8
m = 68.1
c = 12.5
a = "-->"
b = "m/s" 
print "Tiempo - Velocidad"
for t in range (152):
    v = ((m*g/c)*(1-math.exp(-(c/m)*t)))
    print  t, a + "   ", v, b
# Out:
# Tiempo - Velocidad
# 0 -->    0.0 m/s
# 1 -->    8.9531822079 m/s
# 2 -->    16.4049808029 m/s
# 3 -->    22.6071669095 m/s
# 4 -->    27.7692914639 m/s
# 5 -->    32.0657652324 m/s
# 6 -->    35.6417515631 m/s
# 7 -->    38.6180709651 m/s
# 8 -->    41.0952832258 m/s
# 9 -->    43.1570849869 m/s
# 10 -->    44.8731375713 m/s
# 11 -->    46.3014206042 m/s
# 12 -->    47.4901909486 m/s
# 13 -->    48.4796131425 m/s
# 14 -->    49.3031164225 m/s
# 15 -->    49.988524185 m/s
# 16 -->    50.5589940452 m/s
# 17 -->    51.0338002541 m/s
# 18 -->    51.4289849112 m/s
# 19 -->    51.7578999723 m/s
# 20 -->    52.0316583671 m/s
# 21 -->    52.2595094679 m/s
# 22 -->    52.4491515944 m/s
# 23 -->    52.606992114 m/s
# 24 -->    52.7383639252 m/s
# 25 -->    52.847705638 m/s
# 26 -->    52.9387115399 m/s
# 27 -->    53.0144564132 m/s
# 28 -->    53.0774994216 m/s
# 29 -->    53.1299705754 m/s
# 30 -->    53.1736426979 m/s
# 31 -->    53.2099913228 m/s
# 32 -->    53.2402445473 m/s
# ...
