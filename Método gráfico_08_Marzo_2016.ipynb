# %%
import math
import matplotlib.pyplot as plt
t,y,z,ar1,ar2=[],[],[],[],[]
# %matplotlib inline
for i in range (6):
    x2=(-1.5)*i +9
    ar1.append(x2)
    x2b=0.5*i +1
    ar2.append(x2b)
    t.append(i)
    z.append(x2)
    y.append(x2b)
    if (x2==x2b):
        a=x2
        print "La solución para x2 es : "+ str(x2)
print "La solución de x1 es : "+str((2*a)-2)

plt.plot(t,z, linewidth='2.0', label='3x1+2x2=18')
plt.plot(t,y, linewidth='2.0',label='-x1+2x2=2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# La solución para x2 es : 3.0
# La solución de x1 es : 4.0
